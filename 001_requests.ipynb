# %%
#Install dependencies
# %pip install anthropic python-dotenv

# Load environment variables
from dotenv import load_dotenv
import os

load_dotenv()

# Check if API key is loaded
api_key = os.getenv('ANTHROPIC_API_KEY')
if not api_key or api_key == 'your-anthropic-api-key-here':
    print("⚠️  API key not found or using placeholder!")
    print("Please update your .env file with a valid ANTHROPIC_API_KEY")
    print("Current API key:", api_key)
else:
    print("✅ API key loaded successfully")

# Create an API client
from anthropic import Anthropic

client = Anthropic()
# Trying Claude 4 model name (may not be available yet)
model = "claude-sonnet-4-0"
print(f"Using model: {model}")

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

# Chat function to make requests
def chat(messages):
    message = client.messages.create(
        model=model,
        messages=messages,
        max_tokens=1000,
    )
    return message.content[0].text

# Make a starting list of messages
messages = []

# Add in the initial user question
add_user_message(messages, "Define quantum computing in one sentence.")

# Pass the list of messages into 'chat' to get answer
answer = chat(messages)


# Add Claude response to messages
add_assistant_message(messages, answer)

# Add in the user's follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full conversation context
final_answer = chat(messages)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ✅ API key loaded successfully
# Using model: claude-sonnet-4-0
# Note: you may need to restart the kernel to use updated packages.
# ✅ API key loaded successfully
# Using model: claude-sonnet-4-0
# First response: Quantum computing is a revolutionary computational approach that harnesses quantum mechanical phenomena like superposition and entanglement to process information in ways that can potentially solve certain complex problems exponentially faster than classical computers.
# First response: Quantum computing is a revolutionary computational approach that harnesses quantum mechanical phenomena like superposition and entanglement to process information in ways that can potentially solve certain complex problems exponentially faster than classical computers.
# ...
